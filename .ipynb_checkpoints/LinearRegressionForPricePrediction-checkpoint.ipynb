# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
housing_data = pd.read_csv('datasets/housing.csv')
housing_data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9787     -120.79     36.06                29.0       1916.0           386.0
# 15177    -117.07     33.04                 4.0       2271.0           578.0
# 8770     -118.34     33.79                36.0        716.0           123.0
# 19765    -122.13     40.01                21.0        916.0           194.0
# 154      -122.22     37.81                52.0       2927.0           402.0
#
#        population  households  median_income  median_house_value  \
# 9787       1019.0       314.0         2.4881             87500.0
# 15177       926.0       391.0         3.6437            210100.0
# 8770        388.0       124.0         5.0254            350000.0
# 19765       451.0       178.0         2.1250             63300.0
# 154        1021.0       380.0         8.1564            390100.0
#
#       ocean_proximity
# 9787        <1H OCEAN
# 15177       <1H OCEAN
# 8770        <1H OCEAN
# 19765          INLAND
# 154          NEAR BAY

# %%
housing_data = housing_data.dropna()
housing_data.shape
# Out:
# (20433, 10)

# %%
housing_data.loc[housing_data['median_house_value'] == 500001].count()
# Out:
# longitude             958
# latitude              958
# housing_median_age    958
# total_rooms           958
# total_bedrooms        958
# population            958
# households            958
# median_income         958
# median_house_value    958
# ocean_proximity       958
# dtype: int64

# %%
housing_data = housing_data.drop(housing_data.loc[housing_data['median_house_value'] == 500001].index)
housing_data.shape
# Out:
# (19475, 10)

# %%
housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing_data['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
housing_data = pd.get_dummies(housing_data, columns=['ocean_proximity'])
housing_data.shape
# Out:
# (19475, 14)

# %%
housing_data.sample()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7831    -118.15      33.9                20.0       2850.0           737.0
#
#       population  households  median_income  median_house_value  \
# 7831      1855.0       662.0          2.809            144600.0
#
#       ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 7831                       True                   False
#
#       ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 7831                   False                     False
#
#       ocean_proximity_NEAR OCEAN
# 7831                       False

# %%
X = housing_data.drop('median_house_value', axis=1)
Y = housing_data['median_house_value']

# %%
X.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.2)

# %%
x_train.shape, x_test.shape
# Out:
# ((15580, 13), (3895, 13))

# %%
y_train.shape, y_test.shape
# Out:
# ((15580,), (3895,))

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression().fit(x_train,y_train)

# %%
print("Training_score : ", linear_model.score(x_train,y_train))
# Out:
# Training_score :  0.611901742652714

# %%
predictors = x_train.columns
predictors
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
coef = pd.Series(linear_model.coef_, predictors).sort_values()
print(coef)
# Out:
# ocean_proximity_INLAND        -64410.065679
# ocean_proximity_NEAR BAY      -30661.910365
# ocean_proximity_<1H OCEAN     -24877.545936
# longitude                     -24177.922624
# latitude                      -22259.926401
# ocean_proximity_NEAR OCEAN    -20830.816239
# population                       -30.288241
# total_rooms                       -6.729163
# households                        42.423502
# total_bedrooms                    90.939802
# housing_median_age               914.367325
# median_income                  38253.507711
# ocean_proximity_ISLAND        140780.338219
# dtype: float64

# %%
y_pred = linear_model.predict(x_test)

# %%
df_pred_actual = pd.DataFrame({'predicted': y_pred, 'actual': y_test})
df_pred_actual.head(10)
# Out:
#            predicted    actual
# 3420   175700.735991  133300.0
# 3360    77492.609999  105700.0
# 18689  228774.236483  190800.0
# 19553   62373.003701   75000.0
# 15706  197999.247499  117500.0
# 20399  302733.937416  251400.0
# 6985   253542.228314  232400.0
# 9171   144575.510283  155000.0
# 1289   148933.324794  146800.0
# 18225  319353.438940  343300.0

# %%
from sklearn.metrics import r2_score
print("Testing_score : ", r2_score(y_test, y_pred))
# Out:
# Testing_score :  0.6170420923321016

# %%
fig, ax = plt.subplots(figsize=(12,8))
plt.scatter(y_test,y_pred)
plt.show()

# %%
df_pred_actual_sample = df_pred_actual.sample(100)
df_pred_actual_sample = df_pred_actual_sample.reset_index()

# %%
df_pred_actual_sample.head()
# Out:
#    index      predicted    actual
# 0   3166   81462.898521   61400.0
# 1  15836  263557.384018  338800.0
# 2  17763  217175.593112  194500.0
# 3  18220  291013.604258  192200.0
# 4  20600  109220.120278   71700.0

# %%
plt.figure(figsize=(20, 10))

plt.plot(df_pred_actual_sample['predicted'], label='Predicted')
plt.plot(df_pred_actual_sample['actual'], label='Actual')

plt.ylabel('median_house_value')

plt.legend()
plt.show()
